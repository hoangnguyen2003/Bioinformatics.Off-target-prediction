# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 75.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# Successfully installed scikit-learn-1.5.0

# %%
# !pip install xlrd==1.2.0
# Out:
# Collecting xlrd==1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0

# %%
# !git clone https://github.com/hoangnguyen2003/Bioinformatics.Off-target-prediction.git
# Out:
# Cloning into 'Bioinformatics.Off-target-prediction'...
# remote: Enumerating objects: 516, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 516 (delta 31), reused 52 (delta 17), pack-reused 450
# Receiving objects: 100% (516/516), 34.70 MiB | 15.75 MiB/s, done.
# Resolving deltas: 100% (249/249), done.

# %%
cd /kaggle/working/Bioinformatics.Off-target-prediction
# Out:
# /kaggle/working/Bioinformatics.Off-target-prediction

# %%
# !python model/train.py --dataset_name ttiss.csv \
--model_name ttiss_2 --roc_image_name ttiss_2 \
--retrain 1 --sampling 1
# Out:
# 2024-05-30 00:11:15.175227: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 00:11:15.175347: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 00:11:15.309194: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ main_input          │ (None, 1, 23, 4)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 1, 23, 10) │        170 │ main_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 1, 23, 10) │        330 │ main_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 1, 23, 10) │        490 │ main_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 1, 23, 10) │        810 │ main_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 1, 23, 40) │          0 │ conv2d[0][0],     │
# │ (Concatenate)       │                   │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1, 23, 40) │        160 │ concatenate[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 1, 5, 40)  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 200)       │          0 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 100)       │     20,100 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 23)        │      2,323 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 23)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 2)         │         48 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,431 (95.43 KB)
#  Trainable params: 24,351 (95.12 KB)
#  Non-trainable params: 80 (320.00 B)
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717028102.290882     132 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - acc: 0.8404 - loss: 0.6483 - val_acc: 0.9333 - val_loss: 0.4840
# Epoch 2/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9921 - loss: 0.4076 - val_acc: 0.9444 - val_loss: 0.3097
# Epoch 3/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9931 - loss: 0.2350 - val_acc: 0.9444 - val_loss: 0.2260
# Epoch 4/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9935 - loss: 0.1486 - val_acc: 0.9222 - val_loss: 0.2179
# Epoch 5/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9945 - loss: 0.1027 - val_acc: 0.9333 - val_loss: 0.2153
# Epoch 6/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9956 - loss: 0.0730 - val_acc: 0.9222 - val_loss: 0.2875
# Epoch 7/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9959 - loss: 0.0532 - val_acc: 0.9667 - val_loss: 0.1508
# Epoch 8/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9960 - loss: 0.0413 - val_acc: 0.9444 - val_loss: 0.2159
# Epoch 9/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9961 - loss: 0.0345 - val_acc: 0.9333 - val_loss: 0.3089
# Epoch 10/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9962 - loss: 0.0306 - val_acc: 0.9444 - val_loss: 0.2669
# Epoch 11/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9962 - loss: 0.0287 - val_acc: 0.9222 - val_loss: 0.3842
# Epoch 12/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.
200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - acc: 0.9970 - loss: 0.0205 - val_acc: 0.9000 - val_loss: 0.5812
# Epoch 41/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9973 - loss: 0.0191 - val_acc: 0.9222 - val_loss: 0.4552
# Epoch 42/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - acc: 0.9971 - loss: 0.0198 - val_acc: 0.8889 - val_loss: 0.5671
# Epoch 43/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9973 - loss: 0.0191 - val_acc: 0.9556 - val_loss: 0.2709
# Epoch 44/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - acc: 0.9971 - loss: 0.0199 - val_acc: 0.9444 - val_loss: 0.3144
# Epoch 45/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9972 - loss: 0.0187 - val_acc: 0.9889 - val_loss: 0.0809
# Epoch 46/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - acc: 0.9973 - loss: 0.0185 - val_acc: 0.8889 - val_loss: 0.6457
# Epoch 47/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9972 - loss: 0.0187 - val_acc: 0.9222 - val_loss: 0.4594
# Epoch 48/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9975 - loss: 0.0174 - val_acc: 0.9000 - val_loss: 0.5887
# Epoch 49/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9973 - loss: 0.0187 - val_acc: 0.9222 - val_loss: 0.4430
# Epoch 50/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - acc: 0.9974 - loss: 0.0179 - val_acc: 0.9444 - val_loss: 0.3263
# Epoch 51/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - acc: 0.9974 - loss: 0.0177 - val_acc: 0.9222 - val_loss: 0.4412
# Epoch 52/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - acc: 0.9975 - loss: 0.0175 - val_acc: 0.9111 - val_loss: 0.5005
# Epoch 53/200
# 5350/5350 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - acc: 0.9973 - loss: 0.0182 - val_acc: 0.8333 - val_loss: 0.9258
# dict_keys(['acc', 'loss', 'val_acc', 'val_loss'])
# 2093/2093 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Accuracy                0.9988
# F1 score                0.6611
# Precision               0.5411
# Recall                  0.8495
# ROC AUC                 0.9968
# PR AUC                  0.5561

# %%
from IPython.display import Image
Image("/kaggle/working/Bioinformatics.Off-target-prediction/images/ttiss_2_11.png")

# %%
from IPython.display import Image
Image("/kaggle/working/Bioinformatics.Off-target-prediction/images/ttiss_2_22.png")

# %%
from IPython.display import Image
Image("/kaggle/working/Bioinformatics.Off-target-prediction/images/ttiss_2.png")

# %%
import os

# Specify the current and new folder names
current_folder_name = 'Bioinformatics.Off-target-prediction'
new_folder_name = 'bbbbb'

# Define the path to the output directory
output_directory = '/kaggle/working/'

# Create the full paths for the current and new folders
current_folder_path = os.path.join(output_directory, current_folder_name)
new_folder_path = os.path.join(output_directory, new_folder_name)

# Rename the folder
try:
    os.rename(current_folder_path, new_folder_path)
    print(f"Folder '{current_folder_name}' renamed to '{new_folder_name}' successfully.")
except FileNotFoundError:
    print(f"Folder '{current_folder_name}' not found.")
except FileExistsError:
    print(f"A folder named '{new_folder_name}' already exists.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Folder 'Bioinformatics.Off-target-prediction' renamed to 'bbbbb' successfully.

# %%
cd /kaggle/working/
# Out:
# /kaggle/working
